# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'SITE': ['Nyachebe', 'Nyachebe', 'Uyoga', 'Uyoga', 'Luanda Nyanza', 'Luanda Nyanza', 'Ngegu', 'Ngegu', 'Matunja', 'Matunja', 'Seka', 'Seka',
             'Dunga', 'Dunga', 'Kichinjio', 'Kichinjio', 'Kagwel', 'Kagwel', 'Luanda Kotieno', 'Luanda Kotieno', 'Usenge', 'Usenge', 'Osieko', 'Osieko'],
    'Distance': [0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100, 0, 100],
    'pH': [7.7, 7.1, 8.4, 8.1, 7.8, 7.8, 8.9, 8.9, 8.1, 8.6, 8.9, 8.9, 7.3, 7.1, 8.7, 8.1, 7.8, 8.7, 8.7, 8.3, 7.3, 8.1, 7.8, 7.8],
    'TEMP': [26.6, 25.7, 26.9, 25.6, 25.1, 24.4, 29.5, 30.0, 26.3, 26.7, 26.5, 28.7, 27.6, 29.0, 28.8, 27.7, 29.7, 27.3, 30.8, 29.3, 25.6, 25.8, 28.2, 27.6],
    'COND': [86.5, 80.3, 107.0, 115.4, 94.2, 65.9, 111.6, 78.0, 134.5, 119.0, 111.0, 109.0, 123.0, 123.8, 120.3, 129.0, 137.4, 115.0, 125.0, 97.0, 116.6, 114.0, 123.5, 123.0],
    'TDS': [63.0, 60.7, 73.0, 73.0, 65.9, 65.9, 85.4, 78.0, 94.0, 89.0, 81.6, 109.0, 87.6, 110.0, 82.0, 129.0, 105.0, 116.0, 84.0, 90.0, 53.0, 90.0, 83.0, 65.0],
    'DO': [4.5, 4.0, 1.8, 1.5, 6.7, 4.0, 7.9, 6.7, 5.4, 5.4, 4.2, 5.8, 4.4, 7.0, 3.6, 3.6, 4.2, 5.2, 4.6, 5.9, 3.4, 4.5, 5.4, 3.7],
    'BOD': [1.9, 1.8, 2.5, 1.8, 2.5, 1.9, 3.5, 4.2, 4.0, 2.5, 1.0, 1.2, 0.6, 0.4, 4.1, 0.8, 3.3, 3.5, 2.2, 2.4, 2.7, 2.8, 3.0, 2.4],
    'TURB': [41.0, 36.5, 12.5, 8.0, 16.0, 4.5, 51.5, 39.5, 43.6, 63.2, 21.0, 5.8, 48.3, 32.2, 69.5, 31.2, 84.1, 36.0, 11.0, 10.0, 1.0, 3.0, 30.1, 27.0],
    'SECC': [0.4, 1.2, 0.6, 0.5, 0.7, 1.3, 1.1, 1.1, 0.4, 0.4, 1.4, 0.2, 0.3, 0.9, 0.3, 1.5, 0.7, 0.6, 0.8, 0.6, 0.4, 0.5, 2.2, 0.5],
    'TSS': [6.1, 7.2, 7.4, 2.0, 7.2, 3.1, 9.1, 8.3, 7.4, 10.4, 6.5, 7.0, 8.0, 12.0, 5.0, 6.3, 5.3, 7.8, 3.0, 12.0, 6.2, 10.8, 7.5, 6.3]
}

df = pd.DataFrame(data)

# %%
fig, axes = plt.subplots(3,3,figsize=(20,15))

sns.boxplot(ax=axes[0,0], x='SITE', y='pH', hue='Distance', data=df)
sns.boxplot(ax=axes[0,1], x='SITE', y='TEMP', hue='Distance', data=df)
sns.boxplot(ax=axes[0,2], x='SITE', y='COND', hue='Distance', data=df)
sns.boxplot(ax=axes[1,0], x='SITE', y='TDS', hue='Distance', data=df)
sns.boxplot(ax=axes[1,1], x='SITE', y='DO', hue='Distance', data=df)
sns.boxplot(ax=axes[1,2], x='SITE', y='BOD', hue='Distance', data=df)
sns.boxplot(ax=axes[2,0], x='SITE', y='TURB', hue='Distance', data=df)
sns.boxplot(ax=axes[2,1], x='SITE', y='SECC', hue='Distance', data=df)
sns.boxplot(ax=axes[2,2], x='SITE', y='TSS', hue='Distance', data=df)

for ax in axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2037/2607482821.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/2607482821.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/2607482821.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/2607482821.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# ...

# %%
plt.figure(figsize=(14,8))
sns.lineplot(data=df, x='SITE', y='pH', hue='Distance')
plt.title('pH levels across fish landing beaches')
plt.xticks(rotation=90)
plt.show()

# %%
fig, axes = plt.subplots(3,3, figsize=(20, 15))

sns.barplot(ax=axes[0,0], x='SITE', y='pH', hue='Distance', data=df)
sns.barplot(ax=axes[0, 1], x='SITE', y='TEMP', hue='Distance', data=df)
sns.barplot(ax=axes[0, 2], x='SITE', y='COND', hue='Distance', data=df)
sns.barplot(ax=axes[1, 0], x='SITE', y='TDS', hue='Distance', data=df)
sns.barplot(ax=axes[1, 1], x='SITE', y='DO', hue='Distance', data=df)
sns.barplot(ax=axes[1, 2], x='SITE', y='BOD', hue='Distance', data=df)
sns.barplot(ax=axes[2, 0], x='SITE', y='TURB', hue='Distance', data=df)
sns.barplot(ax=axes[2, 1], x='SITE', y='SECC', hue='Distance', data=df)
sns.barplot(ax=axes[2, 2], x='SITE', y='TSS', hue='Distance', data=df)

for ax in axes.flatten():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_2037/1601382785.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/1601382785.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/1601382785.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# /tmp/ipykernel_2037/1601382785.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# ...
